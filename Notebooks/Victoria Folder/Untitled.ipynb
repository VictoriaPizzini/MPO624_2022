# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import metpy

# %%
cnames = ['year', 'month', 'day', 'RMM1', 'RMM2', 'phase', 'amplitude', 'final']
filename = 'http://www.bom.gov.au/climate/mjo/graphics/rmm.74toRealtime.txt'
df = pd.read_csv(filename, skiprows=21, delim_whitespace=True, names=cnames)
df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14276\446842512.py in <module>
#       1 cnames = ['year', 'month', 'day', 'RMM1', 'RMM2', 'phase', 'amplitude', 'final']
#       2 filename = 'http://www.bom.gov.au/climate/mjo/graphics/rmm.74toRealtime.txt'
# ----> 3 df = pd.read_csv(filename, skiprows=21, delim_whitespace=True, names=cnames)
#       4 df
#
# ~\miniconda3\envs\MPO624\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
